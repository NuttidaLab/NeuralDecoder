# %%
import os, sys; sys.path.append(os.path.abspath('../'))

# %%
import numpy as np
from inspector.utility import plot_distmat

# %%
energy_frames = np.load('../jobs_for_monkee/outputs/baseline_energy_dist_20_time_step_10_models.npy')

# %%
energy_frames.shape
# Out:
# (20, 10, 10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_distmat_new(distmat, title = "Distance Metric", out_path = None):
    '''Plot a distance matrix
    New method uses Seaborn to create a heatmap
    '''

    # Set the x and y ticks to the labels
    number_of_networks = len(distmat[0])
    labels = [f"Network {i+1}" for i in range(number_of_networks)]

    # Create a new figure
    plt.figure()

    # Plot the heatmap using Seaborn
    ax = sns.heatmap(distmat, cmap='coolwarm', annot=True, fmt=".3f",
                     xticklabels=labels, yticklabels=labels, cbar_kws={'label': 'Distance'})
    ax.set_title(title)

    # if out_path is not None, save the figure to the path
    if out_path is not None:
        ax.figure.savefig(out_path, bbox_inches='tight')
    else:
        plt.show()

# %%
for i in range(energy_frames.shape[0]):
    plot_distmat_new(energy_frames[i], title=f'Energy Distance at time: {i+1}', out_path=f'energy_dist_{i}.png')
